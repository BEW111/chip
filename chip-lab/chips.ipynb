# %%
import asyncio

import pandas as pd

# %%
import firebase_admin
from firebase_admin import credentials, firestore

cred = credentials.Certificate("secrets/bew-chip-firebase-adminsdk-vemhl-9c99057cb8.json")
app = firebase_admin.initialize_app(cred)
db = firestore.client()

# %%
chips = pd.DataFrame([c.to_dict() for c in db.collection(u'users').document(u'UvpqqS3coSbrYGOAQDyz19bEBo83').collection(u'chips').stream()])
chips
# Out:
#            description                                      photo  \
# 0                                                            None
# 1               coding  AF0C7F05-C19B-43A5-90A4-0E2823AE94B7.jpeg
# 2                                                            None
# 3                       F27BCFC3-A018-4C6D-8755-9D66A7947915.jpeg
# 4               Nov 25  0DEC45C9-BE40-467A-962B-466E7E619BB9.jpeg
# 5                       AF91D991-3310-4C62-BD72-6FEC5A5BBC46.jpeg
# 6                       2623B259-399D-4DB1-9293-3EA83A1DD7B9.jpeg
# 7                Test3  60FE77C7-CB73-4FB4-BFE7-FBB32F07E62E.jpeg
# 8                       D180A13C-36DB-48BD-9741-D93ECA10350D.jpeg
# 9           Spaghetti   15DA29A0-85C0-4115-9667-B5F8F5C72517.jpeg
# 10                Test  B65CF823-C2C8-4636-9556-9DFB3754CC4D.jpeg
# 11  Fixed adding chips  3D7A4802-A9FE-438A-815F-4F8A585FBF10.jpeg
# 12                      E72B003E-20AB-4989-9ED2-EEA85EA94113.jpeg
# ...
